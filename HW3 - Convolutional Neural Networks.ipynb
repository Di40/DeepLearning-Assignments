# %% [markdown]
# #**Deep Learning Homework 3: Convolutional Neural Networks**
# ### MSc Computer Science, Data Science, Cybersecurity @UNIPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti, Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
# In this homework, we will explore how to develop a simple Convolutional Neural Network for image classification. We will use the CIFAR-10 dataset. In the first part, we will learn how to develop a simple CNN, while in the second part we will explore the impact of various hyper-parameters on the learning performances.

# %% [markdown]
# # Requirements
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %% [markdown]
# **Disclaimer**: the notebook has been tested in Colab with Python `3.9.16`. Some parts *may* not work as expected using different packages and Python versions.

# %%
print("You are using:")
# !python --version
# Out:
# You are using:
# Python 3.10.11

# %%
# They've just released torch 2.0, but we will use the more stable torch=1.13 along with other supporting libriaries
# !pip3 install pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas~=1.5 in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting torch~=1.13
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.6 MB/s eta 0:00:00
# Collecting torchinfo
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: torchdata~=0.5 in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: torchtext~=0.14 in /usr/local/lib/python3.10/dist-packages (0.15.1)
# Requirement already satisfied: torchvision~=0.14 in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Collecting torchaudio~=0.13
#   Downloading torchaudio-0.13.1-cp310-cp310-manylinux1_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5) (2022.7.1)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch~=1.13) (4.5.0)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 69.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (0.40.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchdata~=0.5) (2.27.1)
# Collecting torchdata~=0.5
#   Downloading torchdata-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 101.7 MB/s eta 0:00:00
# Collecting portalocker>=2.0.0
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata~=0.5) (1.26.15)
# Collecting torchtext~=0.14
#   Downloading torchtext-0.14.1-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext~=0.14) (4.65.0)
# Collecting torchvision~=0.14
#   Downloading torchvision-0.15.1-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 111.3 MB/s eta 0:00:00
#   Downloading torchvision-0.14.1-cp310-cp310-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 63.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision~=0.14) (8.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas~=1.5) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchdata~=0.5) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchdata~=0.5) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchdata~=0.5) (2022.12.7)
# Installing collected packages: torchinfo, portalocker, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch, torchvision, torchtext, torchdata, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
#   Attempting uninstall: torchdata
#     Found existing installation: torchdata 0.6.0
#     Uninstalling torchdata-0.6.0:
#       Successfully uninstalled torchdata-0.6.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.1+cu118
#     Uninstalling torchaudio-2.0.1+cu118:
#       Successfully uninstalled torchaudio-2.0.1+cu118
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 portalocker-2.7.0 torch-1.13.1 torchaudio-0.13.1 torchdata-0.5.1 torchinfo-1.7.2 torchtext-0.14.1 torchvision-0.14.1

# %%
import torch
from torch import nn
from torch.nn import Conv2d, MaxPool2d, Linear
from torchinfo import summary
import torch.nn.functional as F
from torchvision.datasets import CIFAR10
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.transforms import Lambda
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from timeit import default_timer as timer
import warnings
warnings.filterwarnings("ignore") #Conflict of nn.functional.act_f and torch.act_f

print(f"{torch.__version__=}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"{device=}")
# !nvidia-smi --format=csv --query-gpu=index,name,driver_version,memory.total,memory.used,memory.free

# Set seed for reproducibility
torch.manual_seed(43)
rng = np.random.default_rng(seed=4242)
# Out:
# torch.__version__='1.13.1+cu117'
# device=device(type='cuda')
# index, name, driver_version, memory.total [MiB], memory.used [MiB], memory.free [MiB]
# 0, Tesla T4, 525.85.12, 15360 MiB, 3 MiB, 15098 MiB

# %% [markdown]
# # Exercise 3.1: Simple CNN

# %% [markdown]
# ## Data Loading and Preprocessing [TO COMPLETE]
#
#
# We will use the `CIFAR-10` dataset.The dataset consists of $60.000$ images in $10$ classes, with $6.000$ images per class. There are $50.000$ training images and $10.000$ test images. Each sample is a $32\times32$ pixels color image (thus with an extra $\times3$ dimensions for the colors channels), associated with a label from one of the classes:
#
# ```python
# classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
# ```
#
# We will divide the dataset in training, testing and validation set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of deep network.

# %% [markdown]
# **[TO COMPLETE]**
#
# In the standard dataset, each pixel intensity is represented by a `uint8` (byte) from $0$ to $255$. As a preprocessing step, we will rescale these values in the range $[0,1]$. You should write a simple so-called MinMaxScaler which takes as input a PIL Image (a specific format for images in Python) and rescales it, after making the appropriate type and shape transformations.

# %% [markdown]
# `%STARTCODE`

# %%
def MinMaxScaler(img):#[TO COMPLETE]
  # First, we load the data as numpy array
  img_as_array = np.asarray(img)
  img_as_tensor = torch.from_numpy(img_as_array) # TO COMPLETE: Transform the array to Tensor for PyTorch
  img_as_tensor = img_as_tensor.permute(2, 0, 1)# TO COMPLETE: image is of size (Height, Width, Channels). But torch excepts (C, H, W). Hence, the second thing is to permute.
  normalized_img = img_as_tensor/255.0 # TO COMPLETE: Rescale image pixels form [0,255] to [0,1]
  return normalized_img


'''
NEW DATA LOADING
Note that the previous function must be passed to transforms.Lambda().
'''
dataset = CIFAR10(root='data/', download=True, train=True, transform=transforms.Lambda(MinMaxScaler)) # 50000 samples
test_data = CIFAR10(root='data/', download=True, train=False, transform=transforms.Lambda(MinMaxScaler)) # 10000 samples
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data/
# Files already downloaded and verified

# %% [markdown]
# `%ENDCODE`

# %%
# Let's check the classes and dataset shapes:
classes = dataset.classes
print(f"{classes=}")
print(f"Dataset shape: {dataset.data.shape}")
print(f"Test set shape: {test_data.data.shape}")
# Out:
# classes=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Dataset shape: (50000, 32, 32, 3)
# Test set shape: (10000, 32, 32, 3)

# %%
dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: data/
#     Split: Train
#     StandardTransform
# Transform: Lambda()

# %%
# Let's also check whether the dataset is balanced, i.e. there are the same amount of samples for each class
label_count = {}
for _, idx in dataset:
    label = classes[idx]
    if label not in label_count:
        label_count[label] = 0
    label_count[label] += 1
label_count
# Out:
# {'frog': 5000,
#  'truck': 5000,
#  'deer': 5000,
#  'automobile': 5000,
#  'bird': 5000,
#  'horse': 5000,
#  'ship': 5000,
#  'cat': 5000,
#  'dog': 5000,
#  'airplane': 5000}

# %% [markdown]
# We split the dataset into training/validation sets:

# %%
val_size = 5000
train_size = len(dataset) - val_size

train_data, val_data = random_split(dataset, [train_size, val_size])
print(f"Training samples = {len(train_data)} \nValidation samples = {len(val_data)} \nTest samples = {len(test_data)}")
# Out:
# Training samples = 45000
# Validation samples = 5000
# Test samples = 10000

# %% [markdown]
# Let's see how normalized sample looks like...

# %%
idx = 50 # 51st data sample
print(train_data[idx]) # (image, label) tensors
assert train_data[idx][0].max().item() <= 1., "Check your MinMaxScaler!"
# Out:
# (tensor([[[0.7373, 0.7216, 0.7255,  ..., 0.7922, 0.7922, 0.7882],
#          [0.7216, 0.7059, 0.7137,  ..., 0.7765, 0.7725, 0.7725],
#          [0.7373, 0.7255, 0.7216,  ..., 0.7569, 0.7529, 0.7490],
#          ...,
#          [0.7608, 0.7608, 0.7647,  ..., 0.7647, 0.7765, 0.7686],
#          [0.8039, 0.8000, 0.8039,  ..., 0.8157, 0.8157, 0.8000],
#          [0.8235, 0.8157, 0.8157,  ..., 0.7922, 0.8000, 0.7804]],
#
#         [[0.6902, 0.6784, 0.6824,  ..., 0.7490, 0.7490, 0.7451],
#          [0.6784, 0.6627, 0.6706,  ..., 0.7333, 0.7294, 0.7294],
#          [0.6941, 0.6824, 0.6784,  ..., 0.7137, 0.7098, 0.7059],
#          ...,
#          [0.7137, 0.7098, 0.7137,  ..., 0.7137, 0.7255, 0.7176],
#          [0.7569, 0.7569, 0.7608,  ..., 0.7725, 0.7725, 0.7569],
#          [0.7804, 0.7725, 0.7725,  ..., 0.7490, 0.7569, 0.7373]],
#
#         [[0.6745, 0.6627, 0.6667,  ..., 0.7333, 0.7333, 0.7294],
#          [0.6588, 0.6471, 0.6549,  ..., 0.7176, 0.7137, 0.7137],
#          [0.6784, 0.6667, 0.6627,  ..., 0.6980, 0.6941, 0.6902],
#          ...,
#          [0.6863, 0.6863, 0.6902,  ..., 0.6941, 0.7020, 0.6980],
#          [0.7412, 0.7412, 0.7451,  ..., 0.7569, 0.7569, 0.7412],
#          [0.7647, 0.7569, 0.7569,  ..., 0.7333, 0.7412, 0.7216]]]), 0)

# %% [markdown]
# ... it's better to see it as images!

# %%
img_chan, img_height, img_width = train_data[idx][0].shape #Channel, Height, Width

# Plots
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        image, label = train_data[index]
        image = image.permute((1, 2, 0)) #C,H,W -> H,W,C
        plt.imshow(image, cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(classes[label])
plt.show()

# %% [markdown]
# Explain in the cell below when using Gradient Descent, why it is usually a good idea to ensure that all the features have a similar scale.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer: **[TO COMPLETE]**
#
# When we train a NN using Gradient Descent, we aim to minimize the cost function. If the input features have **different scales** (the eighenvalues of the Hessian are on dissimilar scales), then the gradients of the cost function with respect to each weight will have different magnitudes. This means that the cost function will have different curvature in different directions. Gradient Descent pushes the optimization towards the steepest direction. This means that the optimization algorithm may take **longer to converge**, or may even **oscillate** and **fail to converge**.
#
# For example, if we have two input features x1 and x2, and x1 has a range of [0,1] while x2 has a range of [0,1000], then the weights associated with x2 will have larger gradients than the weights associated with x1. The cost function will be very steep in the x2 direction and very flat in the x1 direction. This can cause the optimization algorithm to overshoot the minimum and oscillate back and forth.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# Since `train_data`, `val_data` and `test_data` are already PyTorch Datasets, we can use directly DataLoaders to load data from them.

# %%
batch_size = 256
dataloader_training = DataLoader(train_data, batch_size=batch_size, shuffle=True)
dataloader_validation = DataLoader(val_data, batch_size=batch_size)
dataloader_test = DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# ##Model Definition and Training
#
# Let's create a simple CNN. The model will be composed of:
# * One 2D convolutional layer with kernel size 3x3 and 32 output filters/features, that use ReLU activation function
# * a Max Pooling layer (2D) of size 2x2.
# * a Flatten layer
# * a final Dense layer with 10 output neurons (one per class). We do not need to normalize or transform further the outputs, as the `CrossEntropyLoss` takes care of that. Another equivalent approach would be to add a `LogSoftmax` final layer that returns log-probabilities and then use the `NegativeLogLikelihoodLoss`., and with the _softmax_ activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.
# Note that as `input_shape` attribute's value in the first layer report also the third dimension that represents the channel.

# %%
class My_Convolutional_Network(nn.Module):
  def __init__(self, conv_filters=[], kernel_sizes=[], max_pool_sizes=[], act_fs=[], verbose=False):
    super().__init__()

    assert len(conv_filters) == len(kernel_sizes), "length of {conv_filters} and {kernel_sizes} must be same"
    assert len(conv_filters) == len(max_pool_sizes), "length of {conv_filters} and {max_pool_sizes} must be same"
    # max pool of [1, 1] corresponds to no max pool
    assert len(conv_filters) == len(act_fs), "length of {conv_filters} and {act_fs} must be same"

    self.conv_layers = nn.ModuleList()
    self.max_pools = nn.ModuleList()
    self.in_chan = img_chan
    self.in_height = img_height
    self.in_width = img_width
    self.output_dim = len(classes)#10
    self.verbose = verbose
    self.act_fs = act_fs

    height_dimension = self.in_height
    width_dimension = self.in_width

    for maxp1, maxp2 in max_pool_sizes: # as long as padding='same'
      height_dimension = height_dimension // maxp1
      width_dimension = width_dimension // maxp2

    self.inp_dim_to_linear = conv_filters[-1] * height_dimension * width_dimension

    for idx in range(len(conv_filters)):
      if idx == 0:
        #Conv2d(in_channels, out_channels, kernel_size, padding)
        self.conv_layers = self.conv_layers.append(Conv2d(self.in_chan, conv_filters[idx],
                                                          kernel_sizes[idx], padding='same'))
      else:
        self.conv_layers = self.conv_layers.append(Conv2d(conv_filters[idx-1], conv_filters[idx],
                                                          kernel_sizes[idx], padding='same'))
        
      self.max_pools = self.max_pools.append(MaxPool2d(max_pool_sizes[idx]))
    
    self.linear = Linear(self.inp_dim_to_linear, self.output_dim)

  def forward(self, x):

    for idx in range(len(self.conv_layers)):
      from_shape = x.shape[1:]
      active_conv_layer = self.conv_layers[idx]
      active_max_pool = self.max_pools[idx]
      active_act_fun = self.act_fs[idx]
      x = active_max_pool(active_act_fun(active_conv_layer(x)))
      to_shape = x.shape[1:]

      if self.verbose:
        print(f'From dimension [{from_shape}] to dimension [{to_shape}]')

    x = torch.flatten(x, start_dim=1) #if start_dim=1 missed, it also consider batch_size

    if self.verbose:
        print(f'From dimension [{to_shape}] to dimension [{x.shape[1:]}]')
        print(f'From dimension [{x.shape[1:]}] to dimension [{self.output_dim}]')

    return self.linear(x) #no need to use softmax because of the loss function

# %%
conv_filters = [32]
kernel_sizes = [[3, 3]]
max_pool_sizes = [[2, 2]]
act_fs = [F.relu]

num_epochs = 20
lr = 1e-3
model = My_Convolutional_Network(conv_filters, kernel_sizes, max_pool_sizes,
                                 act_fs, False).to(device)
summary(model, input_size=(batch_size, 3, 32, 32)) # Here is a nice summary of our model!
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# My_Convolutional_Network                 [256, 10]                 --
# ├─ModuleList: 1-1                        --                        --
# │    └─Conv2d: 2-1                       [256, 32, 32, 32]         896
# ├─ModuleList: 1-2                        --                        --
# │    └─MaxPool2d: 2-2                    [256, 32, 16, 16]         --
# ├─Linear: 1-3                            [256, 10]                 81,930
# ==========================================================================================
# Total params: 82,826
# Trainable params: 82,826
# Non-trainable params: 0
# Total mult-adds (M): 255.86
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 67.13
# Params size (MB): 0.33
# Estimated Total Size (MB): 70.61
# ==========================================================================================

# %% [markdown]
# Note that the number of parameters mostly depends on the output layers, indeed the parameter sharing techinique used by the 2D convolutional layers allows to significantly reduce the number of learnable weights.
# Now we can train the model.

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
def train(model, optimizer, dataloader_train, dataloader_val, epochs):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(epochs):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (img, label) in enumerate(dataloader_train):
      img, label = img.to(device), label.to(device)
      optimizer.zero_grad()
      logits = model(img)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (img, label) in enumerate(dataloader_val):
            img, label = img.to(device), label.to(device)
            logits = model(img)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(model, optimizer, dataloader_training, dataloader_validation, epochs = num_epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 40.41%, Loss: 1.70189285 ---------------- Val_Acc: 48.24%, Val_Loss: 1.51175725
# epoch: 2 -> Accuracy: 51.79%, Loss: 1.39580381 ---------------- Val_Acc: 52.28%, Val_Loss: 1.37457681
# epoch: 3 -> Accuracy: 55.87%, Loss: 1.28205812 ---------------- Val_Acc: 54.48%, Val_Loss: 1.30282676
# epoch: 4 -> Accuracy: 58.38%, Loss: 1.20780385 ---------------- Val_Acc: 56.88%, Val_Loss: 1.23887622
# epoch: 5 -> Accuracy: 60.32%, Loss: 1.15302789 ---------------- Val_Acc: 56.30%, Val_Loss: 1.23703229
# epoch: 6 -> Accuracy: 61.79%, Loss: 1.11125493 ---------------- Val_Acc: 58.12%, Val_Loss: 1.18751073
# epoch: 7 -> Accuracy: 62.85%, Loss: 1.07723689 ---------------- Val_Acc: 59.14%, Val_Loss: 1.16216910
# epoch: 8 -> Accuracy: 63.95%, Loss: 1.05201387 ---------------- Val_Acc: 60.10%, Val_Loss: 1.15746236
# epoch: 9 -> Accuracy: 64.72%, Loss: 1.02736688 ---------------- Val_Acc: 60.66%, Val_Loss: 1.14107430
# epoch: 10 -> Accuracy: 65.75%, Loss: 1.00156808 ---------------- Val_Acc: 59.78%, Val_Loss: 1.15037942
# epoch: 11 -> Accuracy: 66.71%, Loss: 0.97687930 ---------------- Val_Acc: 61.04%, Val_Loss: 1.10986400
# epoch: 12 -> Accuracy: 67.11%, Loss: 0.96264285 ---------------- Val_Acc: 62.14%, Val_Loss: 1.10400474
# epoch: 13 -> Accuracy: 67.86%, Loss: 0.94512683 ---------------- Val_Acc: 61.66%, Val_Loss: 1.10218978
# epoch: 14 -> Accuracy: 68.21%, Loss: 0.93128043 ---------------- Val_Acc: 62.16%, Val_Loss: 1.09911501
# epoch: 15 -> Accuracy: 68.52%, Loss: 0.92117214 ---------------- Val_Acc: 62.28%, Val_Loss: 1.10748148
# epoch: 16 -> Accuracy: 69.16%, Loss: 0.90106767 ---------------- Val_Acc: 62.44%, Val_Loss: 1.08844399
# epoch: 17 -> Accuracy: 69.75%, Loss: 0.88944733 ---------------- Val_Acc: 61.86%, Val_Loss: 1.10031104
# epoch: 18 -> Accuracy: 69.80%, Loss: 0.87850642 ---------------- Val_Acc: 62.26%, Val_Loss: 1.10958230
# epoch: 19 -> Accuracy: 70.45%, Loss: 0.86510843 ---------------- Val_Acc: 62.34%, Val_Loss: 1.09025896
# epoch: 20 -> Accuracy: 70.68%, Loss: 0.85621011 ---------------- Val_Acc: 63.66%, Val_Loss: 1.07131672
# Training time in second: 154.889376474

# %%
def plot_learning_acc_and_loss(loss_tr, acc_tr, loss_val, acc_val):

    plt.figure(figsize=(8, 10))

    plt.subplot(2, 1, 1)
    plt.grid()
    plt.plot(range(num_epochs), acc_tr, label='acc_training')
    plt.plot(range(num_epochs), acc_val, label='acc_validation')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='best')

    plt.subplot(2, 1, 2)
    plt.grid()
    plt.plot(range(num_epochs), loss_tr, label='loss_training')
    plt.plot(range(num_epochs), loss_val, label='loss_validation')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='best')

    plt.show()

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# Finally, we test the model:

# %%
def test(model, dataloader_test=dataloader_test):
  model.eval()
  total_acc_test, total_count_test, n_batches_test, loss = 0, 0, 0, 0
  for idx, (img, label) in enumerate(dataloader_test):
      img, label = img.to(device), label.to(device)
      logits = model(img)
      loss += criterion(logits, label)
      total_acc_test += (logits.argmax(1) == label).sum().item()
      total_count_test += label.size(0)
      n_batches_test += 1
  accuracy_test = total_acc_test/total_count_test
  loss_test = loss/n_batches_test
  print(f"Test Loss: {loss_test:.8f}", end=' ---------- ')
  print(f"Test Accuracy: {100*accuracy_test:.4f}%")

# %%
test(model)
# Out:
# Test Loss: 1.05100155 ---------- Test Accuracy: 63.9400%

# %% [markdown]
# Here we see that the test accuracy of our simple CNN is about 64%.

# %% [markdown]
# ## Visualize filters
# Let's now visualize the filters emerged in the first convolutional layer.

# %%
layer_names = []
weights = {}
for name, param in model.named_parameters():
    if param.requires_grad:
        layer_names.append(name)
        weights.setdefault(name, param.data)

conv_weights = weights['conv_layers.0.weight']
print(f"{conv_weights.shape=} <=> [out_dim, inp_dim, kernel_size[0], kernel_size[1]]")
# Out:
# conv_weights.shape=torch.Size([32, 3, 3, 3]) <=> [out_dim, inp_dim, kernel_size[0], kernel_size[1]]

# %%
conv_w0 = conv_weights[:, 0, :, :] # Pick one input dimension

# Rescale weights for visualization
conv_w0 -= torch.min(conv_w0)
conv_w0 /= torch.max(conv_w0)

for r in range(4):
    for c in range(8):
        n=r*8+c
        plt.subplot(4, 8, n+1)
        plt.imshow(conv_w0[n,:,:].cpu(), interpolation='none')
        plt.title(f'chan{n+1}')
        plt.axis('off')
        plt.gray()
plt.show()

# %% [markdown]
# They might be a bit hard to interpret, but it seems that the various filters have learned to detect various corners and edges.

# %% [markdown]
# ## Parameters of a CNN [TO COMPLETE]

# %% [markdown]
# Explain in the cell below:
#
# 1. How are the number of parameters for Conv2D layers are determined? Perform the calculations to calculate the parameters of the Conv2D layer.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer1 : **[TO COMPLETE]**
#
# The number of parameters for a Conv2D layer is determined by the formula:
#
# **param_number = output_channel_number * (input_channel_number * kernel_height * kernel_width + bias)** = 32 * (3 * 3 * 3 + 1) = 32 * 28 = **896**, which is consistent with the model summary.
#
# The Conv2D layer has 32 output channels, 3 input channels (RGB color channels of the input image), and a kernel size of 3x3.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Exercise 3.2: Deep CNN
#
#
# Let's consider a deeper model, more precisly in this exercise we consider a model composed of:
# * One 2D convolutional layer with kernel size 3x3 and 32 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2
# * One 2D convolutional layer with kernel size 2x2 and 16 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2
# * a Flatten layer
# * a final Dense layer with 10 output neurons (one per class), and with the _softmax_ activation function

# %%
conv_filters = [32, 16]
kernel_sizes = [[3, 3], [2, 2]]
max_pool_sizes = [[2, 2], [2, 2]]
act_fs = [F.relu, F.relu]

num_epochs = 20
lr = 1e-3
deep_model = My_Convolutional_Network(conv_filters, kernel_sizes, max_pool_sizes,
                                      act_fs, False).to(device)
summary(deep_model, input_size=(batch_size, 3, 32, 32)) # Here is a nice summary of our model!
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# My_Convolutional_Network                 [256, 10]                 --
# ├─ModuleList: 1-3                        --                        (recursive)
# │    └─Conv2d: 2-1                       [256, 32, 32, 32]         896
# ├─ModuleList: 1-4                        --                        --
# │    └─MaxPool2d: 2-2                    [256, 32, 16, 16]         --
# ├─ModuleList: 1-3                        --                        (recursive)
# │    └─Conv2d: 2-3                       [256, 16, 16, 16]         2,064
# ├─ModuleList: 1-4                        --                        --
# │    └─MaxPool2d: 2-4                    [256, 16, 8, 8]           --
# ├─Linear: 1-5                            [256, 10]                 10,250
# ==========================================================================================
# Total params: 13,210
# Trainable params: 13,210
# Non-trainable params: 0
# Total mult-adds (M): 372.77
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 75.52
# Params size (MB): 0.05
# Estimated Total Size (MB): 78.72
# ==========================================================================================

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(deep_model.parameters(), lr=lr)

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(deep_model, optimizer, dataloader_training, dataloader_validation, epochs = num_epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 34.68%, Loss: 1.84370673 ---------------- Val_Acc: 41.68%, Val_Loss: 1.64520538
# epoch: 2 -> Accuracy: 45.35%, Loss: 1.54580331 ---------------- Val_Acc: 47.34%, Val_Loss: 1.48802912
# epoch: 3 -> Accuracy: 49.92%, Loss: 1.41543579 ---------------- Val_Acc: 50.48%, Val_Loss: 1.40321481
# epoch: 4 -> Accuracy: 52.36%, Loss: 1.34485984 ---------------- Val_Acc: 52.22%, Val_Loss: 1.34661257
# epoch: 5 -> Accuracy: 54.42%, Loss: 1.29349494 ---------------- Val_Acc: 53.80%, Val_Loss: 1.30662155
# epoch: 6 -> Accuracy: 55.85%, Loss: 1.25979865 ---------------- Val_Acc: 55.04%, Val_Loss: 1.28159940
# epoch: 7 -> Accuracy: 56.86%, Loss: 1.23275852 ---------------- Val_Acc: 55.18%, Val_Loss: 1.27000141
# epoch: 8 -> Accuracy: 57.62%, Loss: 1.20511937 ---------------- Val_Acc: 56.34%, Val_Loss: 1.23538852
# epoch: 9 -> Accuracy: 58.82%, Loss: 1.17627001 ---------------- Val_Acc: 57.16%, Val_Loss: 1.21957529
# epoch: 10 -> Accuracy: 59.30%, Loss: 1.16282141 ---------------- Val_Acc: 56.14%, Val_Loss: 1.24192369
# epoch: 11 -> Accuracy: 59.86%, Loss: 1.15109801 ---------------- Val_Acc: 57.60%, Val_Loss: 1.22922766
# epoch: 12 -> Accuracy: 60.56%, Loss: 1.12617934 ---------------- Val_Acc: 58.40%, Val_Loss: 1.18305099
# epoch: 13 -> Accuracy: 60.95%, Loss: 1.11787462 ---------------- Val_Acc: 58.40%, Val_Loss: 1.17476559
# epoch: 14 -> Accuracy: 61.60%, Loss: 1.10141420 ---------------- Val_Acc: 58.64%, Val_Loss: 1.17354584
# epoch: 15 -> Accuracy: 61.75%, Loss: 1.09212232 ---------------- Val_Acc: 58.98%, Val_Loss: 1.16561162
# epoch: 16 -> Accuracy: 62.64%, Loss: 1.07173824 ---------------- Val_Acc: 58.86%, Val_Loss: 1.16370821
# epoch: 17 -> Accuracy: 62.66%, Loss: 1.06816351 ---------------- Val_Acc: 59.84%, Val_Loss: 1.15601277
# epoch: 18 -> Accuracy: 63.00%, Loss: 1.05725622 ---------------- Val_Acc: 59.16%, Val_Loss: 1.17056060
# epoch: 19 -> Accuracy: 63.59%, Loss: 1.04299819 ---------------- Val_Acc: 60.44%, Val_Loss: 1.13349545
# epoch: 20 -> Accuracy: 63.93%, Loss: 1.03474808 ---------------- Val_Acc: 60.98%, Val_Loss: 1.12004459
# Training time in second: 163.86567924299993

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %%
test(deep_model)
# Out:
# Test Loss: 1.07528770 ---------- Test Accuracy: 62.3600%

# %% [markdown]
# Whoa! By developing the deep CNN we dropped the accuracy fom ~64% to ~62%. It seems like we need to develop a better CNN model.

# %% [markdown]
# # Exercise 3.3: A better CNN [TO COMPLETE]
#
# Let's develop a network that performs better than the very simple one above. This exercise aims to explore how much the various hyper-parameters influence the classification capability of the model.
#
# **[TO COMPLETE]**: Your task is to modify some of the hyper-parameters of the previous exercise's network and compare the results. At least one of the models you try should have an improvement in the test set results (generalization) over the result of the model used in the previous exercise.
# In the cell below report only the code of the **best model** that you can find. In addtion, print out its result on the test set, and plot the accuracy and the loss trends in the notebook you return.
# Moreover, for each setup you test, analyze and discuss the obtained results briefly in the last cells at the bottom.
#
# Hint: Each reparameterization should change a different aspect in the network, while the rest of the parameters would stay the same.
# Example parameters to try to change (we suggest to test at least one re-parametrization for each of these categories):
#
# *    number of layers or neurons or filters dimension
# *   activation functions
# *   epochs
# *   batch sizes
# *   max-pooling on/off on certain layers, or pool size

# %% [markdown]
# `%STARTCODE`

# %%
# TO COMPLETE

conv_filters = [32, 32, 32]
kernel_sizes = [[3, 3], [3, 3], [3, 3]] 
max_pool_sizes = [[2, 2], [2, 2], [2, 2]]
act_fs = [F.relu, F.relu, F.relu]
num_epochs = 30
batch_size = 256
num_epochs = 30
lr = 1e-3

new_deep_model = My_Convolutional_Network(conv_filters, kernel_sizes, max_pool_sizes,
                                      act_fs, False).to(device)
                                      
print(summary(new_deep_model, input_size=(batch_size, 3, 32, 32)))

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(new_deep_model.parameters(), lr=lr)

start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(new_deep_model, optimizer, dataloader_training, dataloader_validation, epochs = num_epochs)
end = timer()
print(f"Training time in second: {(end - start)}")

plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

test(new_deep_model)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# My_Convolutional_Network                 [256, 10]                 --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─Conv2d: 2-1                       [256, 32, 32, 32]         896
# ├─ModuleList: 1-6                        --                        --
# │    └─MaxPool2d: 2-2                    [256, 32, 16, 16]         --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─Conv2d: 2-3                       [256, 32, 16, 16]         9,248
# ├─ModuleList: 1-6                        --                        --
# │    └─MaxPool2d: 2-4                    [256, 32, 8, 8]           --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─Conv2d: 2-5                       [256, 32, 8, 8]           9,248
# ├─ModuleList: 1-6                        --                        --
# │    └─MaxPool2d: 2-6                    [256, 32, 4, 4]           --
# ├─Linear: 1-7                            [256, 10]                 5,130
# ==========================================================================================
# Total params: 24,522
# Trainable params: 24,522
# Non-trainable params: 0
# Total mult-adds (M): 993.79
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 88.10
# Params size (MB): 0.10
# Estimated Total Size (MB): 91.34
# ==========================================================================================
# epoch: 1 -> Accuracy: 33.33%, Loss: 1.85331893 ---------------- Val_Acc: 41.06%, Val_Loss: 1.63718438
# epoch: 2 -> Accuracy: 44.91%, Loss: 1.53757656 ---------------- Val_Acc: 46.84%, Val_Loss: 1.49239278
# epoch: 3 -> Accuracy: 50.18%, Loss: 1.40165257 ---------------- Val_Acc: 51.16%, Val_Loss: 1.37068212
# epoch: 4 -> Accuracy: 53.58%, Loss: 1.30409598 ---------------- Val_Acc: 53.78%, Val_Loss: 1.29065359
# epoch: 5 -> Accuracy: 56.42%, Loss: 1.22768044 ---------------- Val_Acc: 56.04%, Val_Loss: 1.21783912
# epoch: 6 -> Accuracy: 58.80%, Loss: 1.17090893 ---------------- Val_Acc: 57.38%, Val_Loss: 1.18811011
# epoch: 7 -> Accuracy: 60.60%, Loss: 1.12038112 ---------------- Val_Acc: 58.58%, Val_Loss: 1.16272676
# epoch: 8 -> Accuracy: 62.35%, Loss: 1.07406354 ---------------- Val_Acc: 60.02%, Val_Loss: 1.13108420
# epoch: 9 -> Accuracy: 63.63%, Loss: 1.03857255 ---------------- Val_Acc: 62.24%, Val_Loss: 1.06441259
# epoch: 10 -> Accuracy: 64.87%, Loss: 1.00960064 ---------------- Val_Acc: 62.52%, Val_Loss: 1.05225551
# epoch: 11 -> Accuracy: 65.76%, Loss: 0.98266286 ---------------- Val_Acc: 62.64%, Val_Loss: 1.03884614
# epoch: 12 -> Accuracy: 66.57%, Loss: 0.95572466 ---------------- Val_Acc: 63.78%, Val_Loss: 1.02551425
# epoch: 13 -> Accuracy: 67.35%, Loss: 0.93587393 ---------------- Val_Acc: 64.96%, Val_Loss: 0.99330121
# epoch: 14 -> Accuracy: 67.92%, Loss: 0.92321765 ---------------- Val_Acc: 64.88%, Val_Loss: 0.99878323
# epoch: 15 -> Accuracy: 68.71%, Loss: 0.89793468 ---------------- Val_Acc: 64.36%, Val_Loss: 0.99371272
# epoch: 16 -> Accuracy: 69.51%, Loss: 0.87868649 ---------------- Val_Acc: 65.82%, Val_Loss: 0.98057812
# epoch: 17 -> Accuracy: 69.98%, Loss: 0.86140203 ---------------- Val_Acc: 66.78%, Val_Loss: 0.94480175
# epoch: 18 -> Accuracy: 70.75%, Loss: 0.84820020 ---------------- Val_Acc: 65.46%, Val_Loss: 0.98350734
# epoch: 19 -> Accuracy: 70.89%, Loss: 0.83827966 ---------------- Val_Acc: 65.22%, Val_Loss: 1.02593613
# epoch: 20 -> Accuracy: 71.34%, Loss: 0.82758588 ---------------- Val_Acc: 66.94%, Val_Loss: 0.94993067
# epoch: 21 -> Accuracy: 71.87%, Loss: 0.81342578 ---------------- Val_Acc: 68.10%, Val_Loss: 0.92448235
# epoch: 22 -> Accuracy: 72.24%, Loss: 0.79848194 ---------------- Val_Acc: 67.66%, Val_Loss: 0.93451512
# epoch: 23 -> Accuracy: 72.41%, Loss: 0.79508591 ---------------- Val_Acc: 68.68%, Val_Loss: 0.90259975
# epoch: 24 -> Accuracy: 73.02%, Loss: 0.78338069 ---------------- Val_Acc: 68.70%, Val_Loss: 0.90671551
# epoch: 25 -> Accuracy: 73.23%, Loss: 0.77061188 ---------------- Val_Acc: 68.90%, Val_Loss: 0.89876747
# epoch: 26 -> Accuracy: 73.52%, Loss: 0.76167005 ---------------- Val_Acc: 69.34%, Val_Loss: 0.90658343
# epoch: 27 -> Accuracy: 74.12%, Loss: 0.74954683 ---------------- Val_Acc: 69.44%, Val_Loss: 0.89297974
# epoch: 28 -> Accuracy: 73.94%, Loss: 0.75001019 ---------------- Val_Acc: 69.14%, Val_Loss: 0.89498073
# epoch: 29 -> Accuracy: 74.47%, Loss: 0.73550510 ---------------- Val_Acc: 69.68%, Val_Loss: 0.88798141
# epoch: 30 -> Accuracy: 74.89%, Loss: 0.73334843 ---------------- Val_Acc: 70.14%, Val_Loss: 0.88009501
# Training time in second: 255.44990855200012
# Test Loss: 0.85797560 ---------- Test Accuracy: 70.5700%

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # [TO COMPLETE] Discuss your results
#
# In the discussion, you need to clearly motivate your choice of hyperparameters, what work and what did not work.
# You also need to plot all the results of experiments you have conducted.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# The best model that I found is... **[TO COMPLETE]**
#
#     conv_filters = [32, 32, 32]
#     kernel_sizes = [[3, 3], [3, 3], [3, 3]]
#     max_pool_sizes = [[2, 2], [2, 2], [2, 2]]
#     act_fs = [F.relu, F.relu, F.relu]
#     num_epochs = 30
#     batch_size = 256
#     num_epochs = 30
#     lr = 1e-3
#
# The achieved accuracy in the test set is... **70.5700%** **[TO COMPLETE]**
#
# Discussion:
# **[TO COMPLETE]**
#
# This model performed well (the best) because it has more capacity to learn complex features from the input images (increased number of Conv2D filters) and more training time (epochs) to optimize (fine-tune) the weights.
#
# The MaxPool2d layers reduce the spatial dimensions of the feature maps, allowing the network to focus on the most salient features. This helps to decrease the number of parameters in the network and to avoid overfitting.

# %% [markdown]
# Besides, I tested also other models:
# * **[TO COMPLETE]**
#
# 1. **number of layers or neurons or filters dimension**
#    * Increase the number of filters in each convolutional layer
#           conv_filters = [64, 32]
#           Training time in seconds: 170.17633639399992
#           Test Loss: 0.95072061 ---------- Test Accuracy: 67.4700%
# ![image.png](data:image/png;base64,...)
#    * Increase the kernel size of the first convolutional layer
#           kernel_sizes = [[5, 5], [2, 2]]
#           Training time in seconds: 157.6891090260001
#           Test Loss: 1.06614244 ---------- Test Accuracy: 62.3200%
# ![image.png](data:image/png;base64,...)
#
#    * Increase the number of convolutional layers (from 2 to 3)
#           conv_filters = [64, 32, 16]
#           kernel_sizes = [[5, 5], [3, 3], [2, 2]]
#           max_pool_sizes = [[2, 2], [2, 2], [2, 2]]
#           act_fs = [F.relu, F.relu, F.relu]
#           Training time in seconds: 185.80166581899994
#           Test Loss: 1.02746296 ---------- Test Accuracy: 64.6100%
# ![image.png](data:image/png;base64,...)
#
# 2. **Change the activation function:**
#    * Sigmoid
#           act_fs = [F.sigmoid, F.sigmoid]
#           Training time in second: 151.0831068839998
#           Test Loss: 1.45257986 ---------- Test Accuracy: 49.5200%
# ![image.png](data:image/png;base64,...)
#    * Tanh
#           act_fs = [F.tanh, F.tanh]
#           Training time in second: 155.60022634100005
#           Test Loss: 1.01537287 ---------- Test Accuracy: 64.6300%
# ![image.png](data:image/png;base64,...)
#    * Leaky ReLU
#           act_fs = [F.leaky_relu, F.leaky_relu]
#           Training time in second: 153.84212730800004
#           Test Loss: 1.06743622 ---------- Test Accuracy: 62.7500%
# ![image.png](data:image/png;base64,...)
#    * ELU (Exponential Linear Unit)
#           act_fs = [F.elu, F.elu]
#           Training time in second: 154.53098520499998
#           Test Loss: 1.02910292 ---------- Test Accuracy: 64.6700%
# ![image.png](data:image/png;base64,...)
#    * Swish
#           act_fs = [F.silu, F.silu]
#           Training time in second: 152.41859384300005
#           Test Loss: 1.11758602 ---------- Test Accuracy: 61.9500%
# ![image.png](data:image/png;base64,...)
#
# 3. **Increase the number of epochs**:
#     * num_epochs = 30
#           Training time in second: 229.98601621099988
#           Test Loss: 1.02441239 ---------- Test Accuracy: 64.6800%
# ![image.png](data:image/png;base64,...)
#     * num_epochs = 50
#           Training time in second: 375.66400782100027
#           Test Loss: 0.98264629 ---------- Test Accuracy: 66.7100%
# ![image.png](data:image/png;base64,...)
#
# 4. **Change the batch size:**
#    * Decrease batch size
#           batch_size = 128
#           Training time in second: 158.51348864600004
#           Test Loss: 1.06886029 ---------- Test Accuracy: 62.8300%
# ![image.png](data:image/png;base64,...)
#    * Increase batch size
#           batch_size = 512
#           Training time in second: 169.592911029
#           Test Loss: 1.04251516 ---------- Test Accuracy: 63.8600%
# ![image.png](data:image/png;base64,...)
#
# 5. **max-pooling on/off on certain layers, or pool size**
#    * Turn off max pooling in the second layer
#           max_pool_sizes = [[2, 2], [1, 1]]
#           Training time in second: 154.12834320899992
#           Test Loss: 1.03603661 ---------- Test Accuracy: 63.8400%
# ![image.png](data:image/png;base64,...)
#    * Increase the max pooling size in the second layer
#           max_pool_sizes = [[2, 2], [3, 3]]
#           Training time in second: 154.51296471900014
#           Test Loss: 1.11100042 ---------- Test Accuracy: 61.2200%
# ![image.png](data:image/png;base64,...)
#
# Discussion:
# **[TO COMPLETE]**
#
# 1. **Number of Layers or Neurons or Filters Dimension**
# * **Increasing the number of filters** in each convolutional layer increases the model's capacity to extract more (different) features from the input image, resulting in a potentially better performance. However, this increases the number of parameters, so the training is computationally more expensive, and our model might overfit.
#   * By incresing the number of filters to [64, 32], we increased the test accuracy to 67.4700%.
# * **Increasing the kernel size** of the first convolutional layer results in capturing larger-scale patterns in the input images, but also to a loss of spatial resolution (information) in the feature maps (harder to identify smaller details in the input).
#   * By increasing the kernel size of the first Conv2D layer to [5, 5] (before it was [3,3]), we got a very small incrase of the test accuracy (62.3200%).
# * **Increasing the number of convolutional layers** increases the depth of the network and allows it to learn more complex features. However, this makes our model computationally more expensive to train, and it may also require more data to prevent overfitting.
#   * Increasing the number of convolutional layers (from 2 to 3), i.e, [64, 32, 16], improved the test accuracy to 64.6100%.
#
# 2. **Activation Function** - The ReLU is the most used activation function in the world right now. However, we experimented with other activation functions as well:
# * **Sigmoid** is not recommended to use as an activation function in DNNs because of the vanishing gradient problem.
# * **Tanh** helps in preventing the vanishing gradient problem in DNNs.
# * **Leaky ReLU** and **ELU** can help in mitigating the dying ReLU problem (when many ReLU neurons only output values of 0), leading to better performance in some cases.
# * **Swish** is a relatively new activation function that has shown promising results in some experiments. It is similar to the sigmoid function, but with a smoother curve that can make it easier to optimize the network.
#   * As expected, Sigmoid performed poorly (49.5200% test accuracy). ELU and Tanh produced the best results: 64.6700% and 64.6300% respectively.
#
# 3. **Number of Epochs** - By increasing the number of epochs, we allow the model to train for longer and potentially improve its performance. However, by doing so, we increase the risk of overfitting if the model is not regularized properly.
#   * Increasing the number of epochs didn't create a significant improvement, but started to introduce overfitting in our model (especially after 25th epoch).
#
# 4. **Batch Size**
#
# * The batch size affects both training time and the noise in the gradient steps. When we use a large batch size, we can train the network faster (fewer gradient descents), but there can be more noise in the gradient. In contrast, using small batch sizes will utilize the data better, but it will take more time to run because we’ll be doing more gradient descents.
#   * We obtained a more significant model improvement (63.8600%) by increasing the batch size (to 512).
#
# 5. **Max-Pooling On/Off on Certain Layers or Pool Size**
#
# * Turning off max pooling in certain layers can help preserve more spatial information in the feature maps, which can be useful in some cases. However, it also increases the risk of overfitting (the model is more complex).
#   * This improved the test accuracy to 63.8400%.
#
# * Increasing the max pooling - We increased the max pooling size in the second layer from [2, 2] to [3, 3]. This means that the feature maps that are output from the second convolutional layer are now downsampled significantly. As a result, the spatial resolution of the feature maps is reduced more, which can make the model less sensitive to small details in the input images. This can lead to a decrease in the accuracy of the model.
#   * In fact, this is what we observe in our results. The test accuracy decreased from 62.27% in the original model to 61.2200%.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Transfer Learning with ResNet18 + ImageNet

# %% [markdown]
# Let's now experiment with transfer learning. We will now load the model structure and weights of a small [ResNet](https://en.wikipedia.org/wiki/Residual_neural_network) (which is still pretty big!), pretrained on the ImageNet dataset. We will then add a fully connected layer at the end of the network and fine-tune it on the CIFAR10 dataset. In this way, we can leverage the knowledge already present in the pre-trained weight and transfer it on our task!

# %%
from torchvision.models import resnet18, ResNet18_Weights

# %%
RESNET18 = resnet18(pretrained=True)
summary(RESNET18, input_size=(batch_size, 3, 32, 32))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [256, 1000]               --
# ├─Conv2d: 1-1                            [256, 64, 16, 16]         9,408
# ├─BatchNorm2d: 1-2                       [256, 64, 16, 16]         128
# ├─ReLU: 1-3                              [256, 64, 16, 16]         --
# ├─MaxPool2d: 1-4                         [256, 64, 8, 8]           --
# ├─Sequential: 1-5                        [256, 64, 8, 8]           --
# │    └─BasicBlock: 2-1                   [256, 64, 8, 8]           --
# │    │    └─Conv2d: 3-1                  [256, 64, 8, 8]           36,864
# │    │    └─BatchNorm2d: 3-2             [256, 64, 8, 8]           128
# │    │    └─ReLU: 3-3                    [256, 64, 8, 8]           --
# │    │    └─Conv2d: 3-4                  [256, 64, 8, 8]           36,864
# │    │    └─BatchNorm2d: 3-5             [256, 64, 8, 8]           128
# │    │    └─ReLU: 3-6                    [256, 64, 8, 8]           --
# │    └─BasicBlock: 2-2                   [256, 64, 8, 8]           --
# │    │    └─Conv2d: 3-7                  [256, 64, 8, 8]           36,864
# │    │    └─BatchNorm2d: 3-8             [256, 64, 8, 8]           128
# │    │    └─ReLU: 3-9                    [256, 64, 8, 8]           --
# │    │    └─Conv2d: 3-10                 [256, 64, 8, 8]           36,864
# │    │    └─BatchNorm2d: 3-11            [256, 64, 8, 8]           128
# │    │    └─ReLU: 3-12                   [256, 64, 8, 8]           --
# ├─Sequential: 1-6                        [256, 128, 4, 4]          --
# │    └─BasicBlock: 2-3                   [256, 128, 4, 4]          --
# │    │    └─Conv2d: 3-13                 [256, 128, 4, 4]          73,728
# │    │    └─BatchNorm2d: 3-14            [256, 128, 4, 4]          256
# │    │    └─ReLU: 3-15                   [256, 128, 4, 4]          --
# │    │    └─Conv2d: 3-16                 [256, 128, 4, 4]          147,456
# │    │    └─BatchNorm2d: 3-17            [256, 128, 4, 4]          256
# │    │    └─Sequential: 3-18             [256, 128, 4, 4]          8,448
# │    │    └─ReLU: 3-19                   [256, 128, 4, 4]          --
# │    └─BasicBlock: 2-4                   [256, 128, 4, 4]          --
# │    │    └─Conv2d: 3-20                 [256, 128, 4, 4]          147,456
# │    │    └─BatchNorm2d: 3-21            [256, 128, 4, 4]          256
# │    │    └─ReLU: 3-22                   [256, 128, 4, 4]          --
# │    │    └─Conv2d: 3-23                 [256, 128, 4, 4]          147,456
# │    │    └─BatchNorm2d: 3-24            [256, 128, 4, 4]          256
# │    │    └─ReLU: 3-25                   [256, 128, 4, 4]          --
# ├─Sequential: 1-7                        [256, 256, 2, 2]          --
# │    └─BasicBlock: 2-5                   [256, 256, 2, 2]          --
# │    │    └─Conv2d: 3-26                 [256, 256, 2, 2]          294,912
# │    │    └─BatchNorm2d: 3-27            [256, 256, 2, 2]          512
# │    │    └─ReLU: 3-28                   [256, 256, 2, 2]          --
# │    │    └─Conv2d: 3-29                 [256, 256, 2, 2]          589,824
# │    │    └─BatchNorm2d: 3-30            [256, 256, 2, 2]          512
# │    │    └─Sequential: 3-31             [256, 256, 2, 2]          33,280
# │    │    └─ReLU: 3-32                   [256, 256, 2, 2]          --
# │    └─BasicBlock: 2-6                   [256, 256, 2, 2]          --
# │    │    └─Conv2d: 3-33                 [256, 256, 2, 2]          589,824
# │    │    └─BatchNorm2d: 3-34            [256, 256, 2, 2]          512
# │    │    └─ReLU: 3-35                   [256, 256, 2, 2]          --
# │    │    └─Conv2d: 3-36                 [256, 256, 2, 2]          589,824
# │    │    └─BatchNorm2d: 3-37            [256, 256, 2, 2]          512
# │    │    └─ReLU: 3-38                   [256, 256, 2, 2]          --
# ├─Sequential: 1-8                        [256, 512, 1, 1]          --
# │    └─BasicBlock: 2-7                   [256, 512, 1, 1]          --
# │    │    └─Conv2d: 3-39                 [256, 512, 1, 1]          1,179,648
# │    │    └─BatchNorm2d: 3-40            [256, 512, 1, 1]          1,024
# │    │    └─ReLU: 3-41                   [256, 512, 1, 1]          --
# │    │    └─Conv2d: 3-42                 [256, 512, 1, 1]          2,359,296
# │    │    └─BatchNorm2d: 3-43            [256, 512, 1, 1]          1,024
# │    │    └─Sequential: 3-44             [256, 512, 1, 1]          132,096
# │    │    └─ReLU: 3-45                   [256, 512, 1, 1]          --
# │    └─BasicBlock: 2-8                   [256, 512, 1, 1]          --
# │    │    └─Conv2d: 3-46                 [256, 512, 1, 1]          2,359,296
# │    │    └─BatchNorm2d: 3-47            [256, 512, 1, 1]          1,024
# │    │    └─ReLU: 3-48                   [256, 512, 1, 1]          --
# │    │    └─Conv2d: 3-49                 [256, 512, 1, 1]          2,359,296
# │    │    └─BatchNorm2d: 3-50            [256, 512, 1, 1]          1,024
# │    │    └─ReLU: 3-51                   [256, 512, 1, 1]          --
# ├─AdaptiveAvgPool2d: 1-9                 [256, 512, 1, 1]          --
# ├─Linear: 1-10                           [256, 1000]               513,000
# ==========================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (G): 9.61
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 209.67
# Params size (MB): 46.76
# Estimated Total Size (MB): 259.57
# ==========================================================================================

# %% [markdown]
# The ResNet has a final fully connected layer that generates 1000 logits corresponding to the classes in the ImageNet dataset. We will re-define it and make it map the features learned in the previous layer to the 10 classes of the CIFAR10 datset.

# %%
linear_layer_input = RESNET18.fc.in_features
linear_layer_output = RESNET18.fc.out_features
print(f"Last layer: {linear_layer_input} -> {linear_layer_output}")
# Out:
# Last layer: 512 -> 1000

# %%
# Replace  the last layer
RESNET18.fc = Linear(linear_layer_input, 10)

# %%
linear_layer_input = RESNET18.fc.in_features
linear_layer_output = RESNET18.fc.out_features
print(f"Last layer: {linear_layer_input} -> {linear_layer_output}")
# Out:
# Last layer: 512 -> 10

# %% [markdown]
# Finally, we "freeze" the other weights in the network so that only the ones in the last layer are trainable.

# %%
for name, param in RESNET18.named_parameters():
    if name == 'fc.weight' or name == 'fc.bias':
      param.requires_grad = True
    else:
      param.requires_grad = False

# %%
RESNET18 = RESNET18.to(device) # Let's now load it to GPU

# %% [markdown]
# Let's consider a smaller subset of CIFAR10 in order to speed-up the fine-tuning process:

# %%
train_idxs = list(range(0, len(train_data), 5))  # 45000/5=9000 Tr
val_idxs = list(range(1, len(val_data), 5))  # 5000/5=1000 Val
test_idxs = list(range(1, len(test_data), 5))  # 10000/5=2000 Ts

train_data_sub = torch.utils.data.Subset(train_data, train_idxs)
val_data_sub = torch.utils.data.Subset(val_data, val_idxs)
test_data_sub = torch.utils.data.Subset(test_data, test_idxs)

# %% [markdown]
# In order to apply custom preprocessing steps that are expected by the pretrained model, we will define a small wrapper around the CIFAR10 dataset.

# %%
weights = ResNet18_Weights.DEFAULT
preprocess = weights.transforms()

class RESDatasetWrapper(Dataset):
  def __init__(self, dataset):
    self.dataset = dataset
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    image, label = self.dataset[idx]
    image = preprocess(image)
    label = torch.tensor(label, dtype=torch.long)
    return image.to(device), label.to(device)

# %%
RES_train_dataset = RESDatasetWrapper(train_data_sub)
RES_val_dataset = RESDatasetWrapper(val_data_sub)
RES_test_dataset = RESDatasetWrapper(test_data_sub)

batch_size=256

RES_dataloader_training = DataLoader(RES_train_dataset, batch_size=batch_size, shuffle=True)
RES_dataloader_validation = DataLoader(RES_val_dataset, batch_size=batch_size)
RES_dataloader_test = DataLoader(RES_test_dataset, batch_size=batch_size)

# %%
num_epochs = 10
lr = 1e-3

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(RESNET18.parameters(), lr=lr)

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(RESNET18, optimizer,
                                                           RES_dataloader_training, 
                                                           RES_dataloader_validation,
                                                           epochs = num_epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 37.76%, Loss: 1.86022890 ---------------- Val_Acc: 57.70%, Val_Loss: 1.42698026
# epoch: 2 -> Accuracy: 65.83%, Loss: 1.19110262 ---------------- Val_Acc: 67.00%, Val_Loss: 1.09797716
# epoch: 3 -> Accuracy: 71.06%, Loss: 0.97711957 ---------------- Val_Acc: 68.30%, Val_Loss: 0.96581745
# epoch: 4 -> Accuracy: 73.11%, Loss: 0.87549907 ---------------- Val_Acc: 69.00%, Val_Loss: 0.90978295
# epoch: 5 -> Accuracy: 74.41%, Loss: 0.81222415 ---------------- Val_Acc: 71.20%, Val_Loss: 0.85919213
# epoch: 6 -> Accuracy: 75.58%, Loss: 0.77394974 ---------------- Val_Acc: 70.60%, Val_Loss: 0.82939744
# epoch: 7 -> Accuracy: 76.40%, Loss: 0.73736602 ---------------- Val_Acc: 71.10%, Val_Loss: 0.80850917
# epoch: 8 -> Accuracy: 76.82%, Loss: 0.71213734 ---------------- Val_Acc: 71.40%, Val_Loss: 0.78616595
# epoch: 9 -> Accuracy: 77.60%, Loss: 0.68450004 ---------------- Val_Acc: 71.50%, Val_Loss: 0.77393931
# epoch: 10 -> Accuracy: 78.02%, Loss: 0.67138487 ---------------- Val_Acc: 73.20%, Val_Loss: 0.76095760
# Training time in second: 357.3706950069991

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %%
test(RESNET18, dataloader_test=RES_dataloader_test)
# Out:
# Test Loss: 0.75488222 ---------- Test Accuracy: 74.1500%

# %% [markdown]
# Notice how we got this result by leveraging a model freely available on the internet and trained on another dataset. That's the power of transfer learning!
